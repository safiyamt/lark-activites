# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Dataset_w6.xlsx - Data.csv')
df
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %%
data=df.groupby('Region').agg({'Surface area (km2)':'sum','Population in thousands (2017)':'sum'})

# %%
plt.figure(figsize=(8,12))
labels=df['Region'].value_counts().index

plt.pie(data['Population in thousands (2017)'],labels=labels,autopct='%1.1f%%')
plt.title('population in thousands (2017)')
plt.show()

# %%
data2=data.sort_values(['Population in thousands (2017)'],ascending=False)
plt.figure(figsize=(8,12))
data2.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
data3=df.sort_values(['GDP per capita (current US$)'],ascending=False).head(10)
labels=data3['country'].value_counts().index
plt.pie(data3['GDP per capita (current US$)'],labels=labels,autopct='%1.1f%%')
plt.title('GDP per capita (current US$) in percentage')
plt.show()

# %%
plt.figure()
sns.barplot(x='country',y='Agricultural production index',data=df.sort_values('Agricultural production index').head(10))
plt.title('top ten countries based on Agricultural production index',fontsize=16)
plt.xlabel('country')
plt.ylabel('Agricultural production index')
plt.xtricks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\XARCHI~1\AppData\Local\Temp/ipykernel_9640/309143158.py in <module>
#       1 plt.figure()
# ----> 2 sns.barplot(x='country',y='Agricultural production index',data=df.sort_values('Agricultural production index').head(10))
#       3 plt.title('top ten countries based on Agricultural production index',fontsize=16)
#       4 plt.xlabel('country')
#       5 plt.ylabel('Agricultural production index')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# # Find out how many countries are there in the data set

# %%
df['country'].count()

# %% [markdown]
# # Find out how many countries with respect to the region are available in the dataset

# %%
df['Region'].value_counts()

# %% [markdown]
# # 4. On average which region has the highest GDP per capita (current US$)

# %%
df1=df.groupby('Region')['GDP per capita (current US$)'].agg(['mean'])
df1[df1['mean']==max(df1['mean'])]

# %% [markdown]
# # On average which region has the highest International trade: Imports (million US$)

# %%
df2=df.groupby('Region')['International trade: Imports (million US$)'].agg(['mean'])
df2[df2['mean']==max(df2['mean'])]

# %% [markdown]
# # Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
df3=df.groupby('Region')['GDP per capita (current US$)'].agg(['std'])
df3[df3['std']==min(df3['std'])]
